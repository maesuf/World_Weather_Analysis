# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 809

# %%
# Import the requests library.
import requests
import json

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | ahipara
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | horki
# Processing Record 7 of Set 1 | fethiye
# Processing Record 8 of Set 1 | bud
# Processing Record 9 of Set 1 | nouadhibou
# Processing Record 10 of Set 1 | darnah
# Processing Record 11 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | tiarei
# Processing Record 18 of Set 1 | dakar
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 1 | nanortalik
# Processing Record 25 of Set 1 | kurilsk
# Processing Record 26 of Set 1 | yerbogachen
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | soyo
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | luderitz
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | mana
# Processing Record 42 of Set 1 | gebre guracha
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | sao joao da barra
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | ostrovnoy
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | srednekolymsk
# Processing Record 49 of Set 1 | nome
# Processing Record 50 of Set 1 | molchanovo
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | bahia blanca
# Processing Record 4 of Set 2 | shelburne
# Processing Record 5 of Set 2 | salekhard
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | kaoma
# Processing Record 8 of Set 2 | cookeville
# Processing Record 9 of Set 2 | aksarka
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | ucluelet
# Processing Record 12 of Set 2 | oranjemund
# Processing Record 13 of Set 2 | clyde river
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | saint anthony
# Processing Record 18 of Set 2 | paamiut
# Processing Record 19 of Set 2 | ambilobe
# Processing Record 20 of Set 2 | cockburn town
# Processing Record 21 of Set 2 | taltal
# Processing Record 22 of Set 2 | marsa matruh
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | jining
# Processing Record 25 of Set 2 | mogadishu
# Processing Record 26 of Set 2 | jijiga
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | dingle
# Processing Record 29 of Set 2 | nantucket
# Processing Record 30 of Set 2 | tilichiki
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | mosquera
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | takoradi
# Processing Record 39 of Set 2 | kysyl-syr
# Processing Record 40 of Set 2 | les cayes
# Processing Record 41 of Set 2 | mayo
# Processing Record 42 of Set 2 | corumba
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 2 | erenhot
# Processing Record 45 of Set 2 | fort nelson
# Processing Record 46 of Set 2 | la ronge
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | bitung
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | madarounfa
# Processing Record 4 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 3 | zhanaozen
# Processing Record 6 of Set 3 | namerikawa
# Processing Record 7 of Set 3 | bima
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | constitucion
# Processing Record 11 of Set 3 | namibe
# Processing Record 12 of Set 3 | manono
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | busselton
# Processing Record 17 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | half moon bay
# Processing Record 20 of Set 3 | komsomolskiy
# Processing Record 21 of Set 3 | walvis bay
# Processing Record 22 of Set 3 | yarke pole
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | fare
# Processing Record 30 of Set 3 | itapirapua
# Processing Record 31 of Set 3 | maniitsoq
# Processing Record 32 of Set 3 | vilyuysk
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | omaruru
# Processing Record 35 of Set 3 | sungairaya
# Processing Record 36 of Set 3 | ushtobe
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | hermanus
# Processing Record 40 of Set 3 | abonnema
# Processing Record 41 of Set 3 | qaqortoq
# Processing Record 42 of Set 3 | coxim
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | williams lake
# Processing Record 45 of Set 3 | dudinka
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | sandeid
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | acapulco
# Processing Record 50 of Set 3 | ferme-neuve
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | upernavik
# Processing Record 3 of Set 4 | cape town
# Processing Record 4 of Set 4 | goksun
# Processing Record 5 of Set 4 | athabasca
# Processing Record 6 of Set 4 | gurupi
# Processing Record 7 of Set 4 | bayir
# Processing Record 8 of Set 4 | kuttigen
# Processing Record 9 of Set 4 | andenes
# Processing Record 10 of Set 4 | key largo
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | butaritari
# Processing Record 13 of Set 4 | bowen
# Processing Record 14 of Set 4 | banda aceh
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | dubbo
# Processing Record 19 of Set 4 | zelenoborskiy
# Processing Record 20 of Set 4 | buala
# Processing Record 21 of Set 4 | vaini
# Processing Record 22 of Set 4 | krasnoselkup
# Processing Record 23 of Set 4 | lensk
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | mount isa
# Processing Record 26 of Set 4 | nevelsk
# Processing Record 27 of Set 4 | diamantino
# Processing Record 28 of Set 4 | puerto ayora
# Processing Record 29 of Set 4 | avera
# Processing Record 30 of Set 4 | nicoya
# Processing Record 31 of Set 4 | ambatondrazaka
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | phalodi
# Processing Record 34 of Set 4 | yakeshi
# Processing Record 35 of Set 4 | qaanaaq
# Processing Record 36 of Set 4 | polis
# Processing Record 37 of Set 4 | norsup
# Processing Record 38 of Set 4 | itarema
# Processing Record 39 of Set 4 | seoul
# Processing Record 40 of Set 4 | otjimbingwe
# Processing Record 41 of Set 4 | malinyi
# Processing Record 42 of Set 4 | havelock
# Processing Record 43 of Set 4 | semnan
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | los llanos de aridane
# Processing Record 46 of Set 4 | homer
# Processing Record 47 of Set 4 | kitui
# Processing Record 48 of Set 4 | funtua
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 50 of Set 4 | saint-martin-boulogne
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 5 | puerto escondido
# Processing Record 5 of Set 5 | ilinge
# Processing Record 6 of Set 5 | andros
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | burica
# City not found. Skipping...
# Processing Record 9 of Set 5 | phalia
# Processing Record 10 of Set 5 | korla
# Processing Record 11 of Set 5 | northampton
# Processing Record 12 of Set 5 | kangavar
# Processing Record 13 of Set 5 | pevek
# Processing Record 14 of Set 5 | staryy nadym
# Processing Record 15 of Set 5 | saint-pierre
# Processing Record 16 of Set 5 | tari
# Processing Record 17 of Set 5 | santa lucia
# Processing Record 18 of Set 5 | senno
# Processing Record 19 of Set 5 | jaisinghnagar
# Processing Record 20 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | asfi
# Processing Record 23 of Set 5 | teya
# Processing Record 24 of Set 5 | safita
# Processing Record 25 of Set 5 | burnie
# Processing Record 26 of Set 5 | makhachkala
# Processing Record 27 of Set 5 | ulaangom
# Processing Record 28 of Set 5 | carutapera
# Processing Record 29 of Set 5 | bafq
# Processing Record 30 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 5 | waipawa
# Processing Record 32 of Set 5 | pemba
# Processing Record 33 of Set 5 | ust-nera
# Processing Record 34 of Set 5 | rondonopolis
# Processing Record 35 of Set 5 | nuuk
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | camocim
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | thurso
# Processing Record 40 of Set 5 | yatou
# Processing Record 41 of Set 5 | cidreira
# Processing Record 42 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 5 | herborn
# Processing Record 44 of Set 5 | vao
# Processing Record 45 of Set 5 | mandeville
# Processing Record 46 of Set 5 | bubaque
# Processing Record 47 of Set 5 | sechura
# Processing Record 48 of Set 5 | petatlan
# Processing Record 49 of Set 5 | verkhnyaya inta
# Processing Record 50 of Set 5 | tual
# Processing Record 1 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 6 | medicine hat
# Processing Record 3 of Set 6 | celestun
# Processing Record 4 of Set 6 | najran
# Processing Record 5 of Set 6 | reo
# Processing Record 6 of Set 6 | comodoro rivadavia
# Processing Record 7 of Set 6 | beaverlodge
# Processing Record 8 of Set 6 | bara
# Processing Record 9 of Set 6 | la reforma
# Processing Record 10 of Set 6 | robat karim
# Processing Record 11 of Set 6 | portobelo
# Processing Record 12 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 6 | santa maria del oro
# Processing Record 14 of Set 6 | aiken
# Processing Record 15 of Set 6 | losone
# Processing Record 16 of Set 6 | meulaboh
# Processing Record 17 of Set 6 | kenai
# Processing Record 18 of Set 6 | bambous virieux
# Processing Record 19 of Set 6 | san patricio
# Processing Record 20 of Set 6 | balvi
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | tashtyp
# Processing Record 23 of Set 6 | genhe
# Processing Record 24 of Set 6 | soc trang
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | havoysund
# Processing Record 27 of Set 6 | geraldton
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | mahibadhoo
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | puerto carreno
# Processing Record 32 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 6 | camacha
# Processing Record 34 of Set 6 | delta
# Processing Record 35 of Set 6 | aloleng
# Processing Record 36 of Set 6 | irati
# Processing Record 37 of Set 6 | sturgeon bay
# Processing Record 38 of Set 6 | vardo
# Processing Record 39 of Set 6 | sitka
# Processing Record 40 of Set 6 | santo tomas
# Processing Record 41 of Set 6 | goroka
# Processing Record 42 of Set 6 | kungurtug
# Processing Record 43 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 6 | north myrtle beach
# Processing Record 45 of Set 6 | itapui
# Processing Record 46 of Set 6 | henderson
# Processing Record 47 of Set 6 | le port
# Processing Record 48 of Set 6 | humboldt
# Processing Record 49 of Set 6 | moose factory
# Processing Record 50 of Set 6 | nagireddipalle
# City not found. Skipping...
# Processing Record 1 of Set 7 | tasiilaq
# Processing Record 2 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 7 | kunashak
# Processing Record 4 of Set 7 | lichuan
# Processing Record 5 of Set 7 | mecca
# Processing Record 6 of Set 7 | trinidad
# Processing Record 7 of Set 7 | praia
# Processing Record 8 of Set 7 | troitskoye
# Processing Record 9 of Set 7 | bonavista
# Processing Record 10 of Set 7 | kavaratti
# Processing Record 11 of Set 7 | xuddur
# Processing Record 12 of Set 7 | molodizhne
# Processing Record 13 of Set 7 | paragould
# Processing Record 14 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 7 | goderich
# Processing Record 16 of Set 7 | aswan
# Processing Record 17 of Set 7 | ekhabi
# Processing Record 18 of Set 7 | yarmouth
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | mbanza-ngungu
# Processing Record 21 of Set 7 | ikirun
# Processing Record 22 of Set 7 | praia da vitoria
# Processing Record 23 of Set 7 | zeya
# Processing Record 24 of Set 7 | angoche
# Processing Record 25 of Set 7 | warner robins
# Processing Record 26 of Set 7 | cozumel
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | san bartolome de tirajana
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | mokolo
# Processing Record 31 of Set 7 | oriximina
# Processing Record 32 of Set 7 | ekibastuz
# Processing Record 33 of Set 7 | hovd
# Processing Record 34 of Set 7 | hofn
# Processing Record 35 of Set 7 | togur
# Processing Record 36 of Set 7 | eureka
# Processing Record 37 of Set 7 | marsh harbour
# Processing Record 38 of Set 7 | grindavik
# Processing Record 39 of Set 7 | vitim
# Processing Record 40 of Set 7 | liberal
# Processing Record 41 of Set 7 | honningsvag
# Processing Record 42 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 7 | progreso
# Processing Record 44 of Set 7 | guilin
# Processing Record 45 of Set 7 | vanderhoof
# Processing Record 46 of Set 7 | yulara
# Processing Record 47 of Set 7 | zhigansk
# Processing Record 48 of Set 7 | salinas
# Processing Record 49 of Set 7 | juegang
# Processing Record 50 of Set 7 | novoagansk
# Processing Record 1 of Set 8 | kiunga
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | tshikapa
# Processing Record 4 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 8 | anqiu
# Processing Record 6 of Set 8 | talnakh
# Processing Record 7 of Set 8 | malindi
# Processing Record 8 of Set 8 | lorengau
# Processing Record 9 of Set 8 | whitecourt
# Processing Record 10 of Set 8 | vanimo
# Processing Record 11 of Set 8 | lakselv
# Processing Record 12 of Set 8 | el campo
# Processing Record 13 of Set 8 | kencong
# Processing Record 14 of Set 8 | ust-ilimsk
# Processing Record 15 of Set 8 | sakharovo
# Processing Record 16 of Set 8 | lamu
# Processing Record 17 of Set 8 | pangnirtung
# Processing Record 18 of Set 8 | oum hadjer
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | kandrian
# Processing Record 21 of Set 8 | manado
# Processing Record 22 of Set 8 | nouakchott
# Processing Record 23 of Set 8 | seymchan
# Processing Record 24 of Set 8 | divnomorskoye
# Processing Record 25 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 8 | buraydah
# Processing Record 28 of Set 8 | deputatskiy
# Processing Record 29 of Set 8 | axim
# Processing Record 30 of Set 8 | havre-saint-pierre
# Processing Record 31 of Set 8 | rosetta
# Processing Record 32 of Set 8 | athens
# Processing Record 33 of Set 8 | pathein
# Processing Record 34 of Set 8 | prince rupert
# Processing Record 35 of Set 8 | santa engracia
# Processing Record 36 of Set 8 | lavrentiya
# Processing Record 37 of Set 8 | ketchikan
# Processing Record 38 of Set 8 | freetown
# Processing Record 39 of Set 8 | coahuayana
# Processing Record 40 of Set 8 | kaseda
# Processing Record 41 of Set 8 | plettenberg bay
# Processing Record 42 of Set 8 | coquimbo
# Processing Record 43 of Set 8 | viedma
# Processing Record 44 of Set 8 | sunndalsora
# Processing Record 45 of Set 8 | gohpur
# Processing Record 46 of Set 8 | varadero
# Processing Record 47 of Set 8 | necochea
# Processing Record 48 of Set 8 | alofi
# Processing Record 49 of Set 8 | hasaki
# Processing Record 50 of Set 8 | assare
# Processing Record 1 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 2 of Set 9 | alugan
# Processing Record 3 of Set 9 | rio gallegos
# Processing Record 4 of Set 9 | cape coast
# Processing Record 5 of Set 9 | davenda
# Processing Record 6 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | shymkent
# Processing Record 9 of Set 9 | fevik
# Processing Record 10 of Set 9 | yermakovskoye
# Processing Record 11 of Set 9 | stykkisholmur
# Processing Record 12 of Set 9 | bethlehem
# Processing Record 13 of Set 9 | esperance
# Processing Record 14 of Set 9 | igrim
# Processing Record 15 of Set 9 | betsiamites
# Processing Record 16 of Set 9 | la sarre
# Processing Record 17 of Set 9 | kahului
# Processing Record 18 of Set 9 | suluq
# Processing Record 19 of Set 9 | trapani
# Processing Record 20 of Set 9 | mound
# Processing Record 21 of Set 9 | touros
# Processing Record 22 of Set 9 | port-cartier
# Processing Record 23 of Set 9 | kutum
# Processing Record 24 of Set 9 | taoudenni
# Processing Record 25 of Set 9 | thunder bay
# Processing Record 26 of Set 9 | val-david
# Processing Record 27 of Set 9 | hirara
# Processing Record 28 of Set 9 | bemidji
# Processing Record 29 of Set 9 | tarrafal
# Processing Record 30 of Set 9 | gombong
# Processing Record 31 of Set 9 | uruguaiana
# Processing Record 32 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 9 | itaituba
# Processing Record 34 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 9 | haines junction
# Processing Record 36 of Set 9 | malangwa
# Processing Record 37 of Set 9 | novyy urengoy
# Processing Record 38 of Set 9 | anadyr
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | padang
# Processing Record 41 of Set 9 | henties bay
# Processing Record 42 of Set 9 | palana
# Processing Record 43 of Set 9 | bridlington
# Processing Record 44 of Set 9 | vestmannaeyjar
# Processing Record 45 of Set 9 | hobyo
# Processing Record 46 of Set 9 | krasnyy chikoy
# Processing Record 47 of Set 9 | sohbatpur
# Processing Record 48 of Set 9 | belaya gora
# Processing Record 49 of Set 9 | yasnyy
# Processing Record 50 of Set 9 | lagoa
# Processing Record 1 of Set 10 | fernandez
# Processing Record 2 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 10 | keetmanshoop
# Processing Record 4 of Set 10 | cabedelo
# Processing Record 5 of Set 10 | novosil
# Processing Record 6 of Set 10 | nushki
# Processing Record 7 of Set 10 | stornoway
# Processing Record 8 of Set 10 | hazleton
# Processing Record 9 of Set 10 | anzio
# Processing Record 10 of Set 10 | stromness
# Processing Record 11 of Set 10 | banjar
# Processing Record 12 of Set 10 | raghogarh
# Processing Record 13 of Set 10 | karratha
# Processing Record 14 of Set 10 | graaff-reinet
# Processing Record 15 of Set 10 | sinnamary
# Processing Record 16 of Set 10 | roald
# Processing Record 17 of Set 10 | suntar
# Processing Record 18 of Set 10 | turukhansk
# Processing Record 19 of Set 10 | beringovskiy
# Processing Record 20 of Set 10 | lubbock
# Processing Record 21 of Set 10 | college
# Processing Record 22 of Set 10 | davila
# Processing Record 23 of Set 10 | thinadhoo
# Processing Record 24 of Set 10 | aquiraz
# Processing Record 25 of Set 10 | orocue
# Processing Record 26 of Set 10 | fairbanks
# Processing Record 27 of Set 10 | ibra
# Processing Record 28 of Set 10 | mandalgovi
# Processing Record 29 of Set 10 | adrar
# Processing Record 30 of Set 10 | shizunai
# Processing Record 31 of Set 10 | dali
# Processing Record 32 of Set 10 | mega
# Processing Record 33 of Set 10 | port keats
# Processing Record 34 of Set 10 | tupik
# Processing Record 35 of Set 10 | blagoyevo
# Processing Record 36 of Set 10 | tabou
# Processing Record 37 of Set 10 | markova
# Processing Record 38 of Set 10 | kumluca
# Processing Record 39 of Set 10 | la asuncion
# Processing Record 40 of Set 10 | praya
# Processing Record 41 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 10 | severo-yeniseyskiy
# Processing Record 43 of Set 10 | ustikolina
# Processing Record 44 of Set 10 | vysha
# Processing Record 45 of Set 10 | san cristobal
# Processing Record 46 of Set 10 | alta gracia
# Processing Record 47 of Set 10 | amuntai
# Processing Record 48 of Set 10 | basoko
# Processing Record 49 of Set 10 | marawi
# Processing Record 50 of Set 10 | arlit
# Processing Record 1 of Set 11 | sola
# Processing Record 2 of Set 11 | flinders
# Processing Record 3 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 11 | maxixe
# Processing Record 5 of Set 11 | beloha
# Processing Record 6 of Set 11 | chapais
# Processing Record 7 of Set 11 | hefei
# Processing Record 8 of Set 11 | awjilah
# Processing Record 9 of Set 11 | roma
# Processing Record 10 of Set 11 | narsaq
# Processing Record 11 of Set 11 | kidal
# Processing Record 12 of Set 11 | castro daire
# Processing Record 13 of Set 11 | hamilton
# Processing Record 14 of Set 11 | airai
# Processing Record 15 of Set 11 | san carlos de bariloche
# Processing Record 16 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 17 of Set 11 | nioro
# Processing Record 18 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 11 | metsovon
# City not found. Skipping...
# Processing Record 20 of Set 11 | emerald
# Processing Record 21 of Set 11 | svelgen
# Processing Record 22 of Set 11 | luang prabang
# Processing Record 23 of Set 11 | rassvet
# Processing Record 24 of Set 11 | gamba
# Processing Record 25 of Set 11 | dunedin
# Processing Record 26 of Set 11 | cabanas
# Processing Record 27 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 11 | vila
# Processing Record 29 of Set 11 | kattivakkam
# Processing Record 30 of Set 11 | marica
# Processing Record 31 of Set 11 | ontario
# Processing Record 32 of Set 11 | namatanai
# Processing Record 33 of Set 11 | uglegorsk
# Processing Record 34 of Set 11 | camana
# Processing Record 35 of Set 11 | mayumba
# Processing Record 36 of Set 11 | evensk
# Processing Record 37 of Set 11 | sarkikaraagac
# Processing Record 38 of Set 11 | launceston
# Processing Record 39 of Set 11 | dwarka
# Processing Record 40 of Set 11 | nichinan
# Processing Record 41 of Set 11 | margate
# Processing Record 42 of Set 11 | zhezkazgan
# Processing Record 43 of Set 11 | carnot
# Processing Record 44 of Set 11 | naduvattam
# Processing Record 45 of Set 11 | bathsheba
# Processing Record 46 of Set 11 | bwanga
# Processing Record 47 of Set 11 | puerto leguizamo
# Processing Record 48 of Set 11 | koygorodok
# Processing Record 49 of Set 11 | prnjavor
# Processing Record 50 of Set 11 | san jose
# Processing Record 1 of Set 12 | jega
# Processing Record 2 of Set 12 | wum
# Processing Record 3 of Set 12 | jensen beach
# Processing Record 4 of Set 12 | qinzhou
# Processing Record 5 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 6 of Set 12 | srandakan
# Processing Record 7 of Set 12 | ishigaki
# Processing Record 8 of Set 12 | portland
# Processing Record 9 of Set 12 | qianguo
# Processing Record 10 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 12 | kharan
# Processing Record 12 of Set 12 | yambio
# Processing Record 13 of Set 12 | amparafaravola
# Processing Record 14 of Set 12 | ust-maya
# Processing Record 15 of Set 12 | gigmoto
# Processing Record 16 of Set 12 | chulman
# Processing Record 17 of Set 12 | shaunavon
# Processing Record 18 of Set 12 | usinsk
# Processing Record 19 of Set 12 | sakaiminato
# Processing Record 20 of Set 12 | kasane
# Processing Record 21 of Set 12 | vidin
# Processing Record 22 of Set 12 | gogrial
# Processing Record 23 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 12 | boden
# Processing Record 25 of Set 12 | bundaberg
# Processing Record 26 of Set 12 | zhaodong
# Processing Record 27 of Set 12 | marion
# Processing Record 28 of Set 12 | san rafael
# Processing Record 29 of Set 12 | akyab
# Processing Record 30 of Set 12 | kununurra
# Processing Record 31 of Set 12 | tigil
# Processing Record 32 of Set 12 | porto belo
# Processing Record 33 of Set 12 | santiago
# Processing Record 34 of Set 12 | santa vitoria do palmar
# Processing Record 35 of Set 12 | ciudad bolivar
# Processing Record 36 of Set 12 | muros
# Processing Record 37 of Set 12 | midyat
# Processing Record 38 of Set 12 | azuaga
# Processing Record 39 of Set 12 | monte alegre
# Processing Record 40 of Set 12 | alice springs
# Processing Record 41 of Set 12 | ardabil
# Processing Record 42 of Set 12 | mastic beach
# Processing Record 43 of Set 12 | alta floresta
# Processing Record 44 of Set 12 | ilhabela
# Processing Record 45 of Set 12 | sari
# Processing Record 46 of Set 12 | bindi
# Processing Record 47 of Set 12 | auki
# Processing Record 48 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 12 | limoges
# Processing Record 50 of Set 12 | matara
# Processing Record 1 of Set 13 | lingyuan
# Processing Record 2 of Set 13 | almaznyy
# Processing Record 3 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 13 | dezful
# Processing Record 6 of Set 13 | kyabram
# Processing Record 7 of Set 13 | itoman
# Processing Record 8 of Set 13 | puno
# Processing Record 9 of Set 13 | belmonte
# Processing Record 10 of Set 13 | cabo san lucas
# Processing Record 11 of Set 13 | maun
# Processing Record 12 of Set 13 | hay river
# Processing Record 13 of Set 13 | ust-omchug
# Processing Record 14 of Set 13 | redlands
# Processing Record 15 of Set 13 | union city
# Processing Record 16 of Set 13 | viking
# Processing Record 17 of Set 13 | illapel
# Processing Record 18 of Set 13 | rychnov nad kneznou
# Processing Record 19 of Set 13 | grand gaube
# Processing Record 20 of Set 13 | san ramon
# Processing Record 21 of Set 13 | gravdal
# Processing Record 22 of Set 13 | puerto del rosario
# Processing Record 23 of Set 13 | ambon
# Processing Record 24 of Set 13 | kalmunai
# Processing Record 25 of Set 13 | sorland
# Processing Record 26 of Set 13 | zhob
# Processing Record 27 of Set 13 | yian
# City not found. Skipping...
# Processing Record 28 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 13 | vila franca do campo
# Processing Record 30 of Set 13 | qandala
# Processing Record 31 of Set 13 | burns lake
# Processing Record 32 of Set 13 | alyangula
# Processing Record 33 of Set 13 | erzin
# Processing Record 34 of Set 13 | misratah
# Processing Record 35 of Set 13 | ofunato
# Processing Record 36 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 13 | owerri
# Processing Record 38 of Set 13 | lai
# Processing Record 39 of Set 13 | khonsa
# Processing Record 40 of Set 13 | puerto narino
# Processing Record 41 of Set 13 | umba
# Processing Record 42 of Set 13 | gat
# Processing Record 43 of Set 13 | valdivia
# Processing Record 44 of Set 13 | ambulu
# Processing Record 45 of Set 13 | vaitape
# Processing Record 46 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 13 | nagua
# Processing Record 48 of Set 13 | jurado
# Processing Record 49 of Set 13 | roberval
# Processing Record 50 of Set 13 | benguela
# Processing Record 1 of Set 14 | san matias
# Processing Record 2 of Set 14 | nokaneng
# Processing Record 3 of Set 14 | volosovo
# Processing Record 4 of Set 14 | pauleni-ciuc
# Processing Record 5 of Set 14 | leisure city
# Processing Record 6 of Set 14 | harnai
# Processing Record 7 of Set 14 | sao marcos
# Processing Record 8 of Set 14 | emba
# Processing Record 9 of Set 14 | octeville
# Processing Record 10 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 11 of Set 14 | bonthe
# Processing Record 12 of Set 14 | raudeberg
# Processing Record 13 of Set 14 | merauke
# Processing Record 14 of Set 14 | nhulunbuy
# Processing Record 15 of Set 14 | astoria
# Processing Record 16 of Set 14 | lata
# Processing Record 17 of Set 14 | tangshan
# Processing Record 18 of Set 14 | dalinghe
# City not found. Skipping...
# Processing Record 19 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 20 of Set 14 | neuquen
# Processing Record 21 of Set 14 | lasa
# Processing Record 22 of Set 14 | kyritz
# Processing Record 23 of Set 14 | fukue
# Processing Record 24 of Set 14 | powell river
# Processing Record 25 of Set 14 | loviisa
# Processing Record 26 of Set 14 | saint-francois
# Processing Record 27 of Set 14 | batticaloa
# Processing Record 28 of Set 14 | sobolevo
# Processing Record 29 of Set 14 | kochevo
# Processing Record 30 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 14 | takab
# Processing Record 32 of Set 14 | fort saint james
# Processing Record 33 of Set 14 | kuchera
# Processing Record 34 of Set 14 | nalut
# Processing Record 35 of Set 14 | kupang
# Processing Record 36 of Set 14 | panama city
# Processing Record 37 of Set 14 | gwadar
# Processing Record 38 of Set 14 | faya
# Processing Record 39 of Set 14 | jiwani
# Processing Record 40 of Set 14 | rajaldesar
# Processing Record 41 of Set 14 | taicheng
# Processing Record 42 of Set 14 | mairana
# Processing Record 43 of Set 14 | vestmanna
# Processing Record 44 of Set 14 | pionerskiy
# Processing Record 45 of Set 14 | victor harbor
# Processing Record 46 of Set 14 | brae
# Processing Record 47 of Set 14 | kyrylivka
# Processing Record 48 of Set 14 | roscommon
# Processing Record 49 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 14 | semey
# Processing Record 1 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 15 | tazmalt
# Processing Record 3 of Set 15 | bulawayo
# Processing Record 4 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 15 | yuncheng
# Processing Record 6 of Set 15 | alunitdag
# City not found. Skipping...
# Processing Record 7 of Set 15 | birao
# Processing Record 8 of Set 15 | mahenge
# Processing Record 9 of Set 15 | neftekamsk
# Processing Record 10 of Set 15 | san juan
# Processing Record 11 of Set 15 | saquarema
# Processing Record 12 of Set 15 | batsfjord
# Processing Record 13 of Set 15 | quatre cocos
# Processing Record 14 of Set 15 | shubarkuduk
# Processing Record 15 of Set 15 | hervey bay
# Processing Record 16 of Set 15 | caldwell
# Processing Record 17 of Set 15 | abha
# Processing Record 18 of Set 15 | broska
# Processing Record 19 of Set 15 | nizwa
# Processing Record 20 of Set 15 | tautira
# Processing Record 21 of Set 15 | tapes
# Processing Record 22 of Set 15 | calabozo
# Processing Record 23 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 24 of Set 15 | saint-joseph
# Processing Record 25 of Set 15 | along
# Processing Record 26 of Set 15 | belyy yar
# Processing Record 27 of Set 15 | te anau
# Processing Record 28 of Set 15 | sumbe
# Processing Record 29 of Set 15 | jumla
# Processing Record 30 of Set 15 | amapa
# Processing Record 31 of Set 15 | tank
# Processing Record 32 of Set 15 | kirakira
# Processing Record 33 of Set 15 | palmer
# Processing Record 34 of Set 15 | weihe
# Processing Record 35 of Set 15 | berdigestyakh
# Processing Record 36 of Set 15 | isangel
# Processing Record 37 of Set 15 | formosa
# Processing Record 38 of Set 15 | formosa do rio preto
# Processing Record 39 of Set 15 | maceio
# Processing Record 40 of Set 15 | lasem
# Processing Record 41 of Set 15 | gorontalo
# Processing Record 42 of Set 15 | waingapu
# Processing Record 43 of Set 15 | denpasar
# Processing Record 44 of Set 15 | jalu
# Processing Record 45 of Set 15 | san lorenzo
# Processing Record 46 of Set 15 | anloga
# Processing Record 47 of Set 15 | poum
# Processing Record 48 of Set 15 | oga
# Processing Record 49 of Set 15 | nisia floresta
# Processing Record 50 of Set 15 | aksu
# Processing Record 1 of Set 16 | jaipur hat
# City not found. Skipping...
# Processing Record 2 of Set 16 | shingu
# Processing Record 3 of Set 16 | kalabugao
# City not found. Skipping...
# Processing Record 4 of Set 16 | port-gentil
# Processing Record 5 of Set 16 | kangaba
# Processing Record 6 of Set 16 | columbus
# Processing Record 7 of Set 16 | mocuba
# Processing Record 8 of Set 16 | kettering
# Processing Record 9 of Set 16 | creston
# Processing Record 10 of Set 16 | trat
# Processing Record 11 of Set 16 | yumen
# Processing Record 12 of Set 16 | xining
# Processing Record 13 of Set 16 | abu samrah
# Processing Record 14 of Set 16 | bahia de caraquez
# Processing Record 15 of Set 16 | virginia beach
# Processing Record 16 of Set 16 | whitianga
# Processing Record 17 of Set 16 | harper
# Processing Record 18 of Set 16 | kudahuvadhoo
# Processing Record 19 of Set 16 | kropachevo
# Processing Record 20 of Set 16 | mehamn
# Processing Record 21 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 16 | aykhal
# Processing Record 24 of Set 16 | nadapuram
# Processing Record 25 of Set 16 | opole
# Processing Record 26 of Set 16 | lingao
# Processing Record 27 of Set 16 | sur
# Processing Record 28 of Set 16 | kashi
# Processing Record 29 of Set 16 | arawa
# Processing Record 30 of Set 16 | luan
# Processing Record 31 of Set 16 | mae hong son
# Processing Record 32 of Set 16 | buckeye
# Processing Record 33 of Set 16 | aklavik
# Processing Record 34 of Set 16 | kunya
# Processing Record 35 of Set 16 | bell ville
# Processing Record 36 of Set 16 | carlagan
# Processing Record 37 of Set 16 | byron bay
# Processing Record 38 of Set 16 | melchor de mencos
# Processing Record 39 of Set 16 | tazovskiy
# Processing Record 40 of Set 16 | san diego de la union
# Processing Record 41 of Set 16 | chifeng
# Processing Record 42 of Set 16 | tonantins
# Processing Record 43 of Set 16 | balkhash
# Processing Record 44 of Set 16 | casper
# Processing Record 45 of Set 16 | slavutych
# Processing Record 46 of Set 16 | goure
# Processing Record 47 of Set 16 | richards bay
# Processing Record 48 of Set 16 | maraa
# Processing Record 49 of Set 16 | pedernales
# Processing Record 50 of Set 16 | muhos
# Processing Record 1 of Set 17 | magadan
# Processing Record 2 of Set 17 | acandi
# Processing Record 3 of Set 17 | lake havasu city
# Processing Record 4 of Set 17 | mount gambier
# Processing Record 5 of Set 17 | burley
# Processing Record 6 of Set 17 | dinghai
# Processing Record 7 of Set 17 | muravlenko
# Processing Record 8 of Set 17 | mormugao
# Processing Record 9 of Set 17 | igarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Leningradskiy      RU  69.3833  178.4167    -16.71        91          93
# 1         Albany      US  42.6001  -73.9662     23.74        53         100
# 2        Ahipara      NZ -35.1667  173.1667     68.63        57          86
# 3   Punta Arenas      CL -53.1500  -70.9167     48.11        45           9
# 4        Rikitea      PF -23.1203 -134.9692     78.62        71          66
# 5          Horki      BY  54.2861   30.9842     22.05        87          53
# 6        Fethiye      TR  36.6217   29.1164     46.27        74           4
# 7            Bud      US  39.4470  -86.1758     22.69        74         100
# 8     Nouadhibou      MR  20.9310  -17.0347     64.81        77          99
# 9         Darnah      LY  32.7670   22.6367     55.29        72           0
#
#    Wind Speed Current Description
# 0        5.93     overcast clouds
# 1        5.99     overcast clouds
# 2        8.86     overcast clouds
# 3       18.75           clear sky
# 4       12.82       broken clouds
# 5       12.19       broken clouds
# 6        4.21           clear sky
# 7        9.71     overcast clouds
# 8       21.92     overcast clouds
# 9        8.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
